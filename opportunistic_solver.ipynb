# %%
"""Opportunistic Graph Search"""

import numpy as np
import random
import math

from ortools.constraint_solver import routing_enums_pb2
from ortools.constraint_solver import pywrapcp

# %%
def random_node(r=10, center=(0,0)):
    alpha = 2 * math.pi * random.random()
    
    # random radius
    r = r * math.sqrt(random.random())
    
    # calculating coordinates
    x = r * math.cos(alpha) + center[0]
    y = r * math.sin(alpha) + center[1]
    
    return (x, y)

# %%
def init_paths(num_riders, hub_coord):
    riders = ['r{}'.format(x) for x in range(num_riders)]
    paths = {}
    for rider in riders:
        paths[rider] = {
            'nodes_coord': [hub_coord],
            'time_tracker': [],
            'path': [],
            'must_leave': float('inf'),
            'will_return': float('inf'),
            'active': False,
            'completed': []
        }
        
    return paths

# %%
def compute_time_matrix(nodes):
    tm = [[0 for x in range(len(nodes))] for y in range(len(nodes))]
    
    for row, start in enumerate(nodes):
        for col, end in enumerate(nodes):
            x = np.array(start)
            y = np.array(end)
            distance = round(np.linalg.norm(x - y)) # Round to nearest integer
            
            if (end == (0,0)) | (row == col):
                tm[row][col] = distance 
            else:
                tm[row][col] = distance + 5 # We account for the handling time in the time to execute the path
       
    return tm

# %%
def nodes_match(nodes, new_nodes):
    for idx, _ in enumerate(nodes):
        if idx not in new_nodes:
            return False
    
    return True

# %%
def describe_path(rider, path):
    print('Rider {}'.format(rider))
    print('Status {}'.format(path['active']))
    
    all_path = 'Hub => '
    for node in path['path'][1:]:
        all_path += 'Node {} => '.format(node)
    all_path += 'Hub'
    
    print('Time on path: {}'.format(path['will_return'] - path['must_leave']))

# %%
def tsp_path(time_matrix):
    manager = pywrapcp.RoutingIndexManager(len(time_matrix), 1, 0) # Time_matrix, num_riders, depot
    routing = pywrapcp.RoutingModel(manager)
    
    # Time callback, gets the time it takes to travel between two nodes.
    def time_callback(from_index, to_index):
        # Convert from routing variable Index to time matrix NodeIndex.
        from_node = manager.IndexToNode(from_index)
        to_node = manager.IndexToNode(to_index)
        return time_matrix[from_node][to_node]

    transit_callback_index = routing.RegisterTransitCallback(time_callback)
    
    routing.SetArcCostEvaluatorOfAllVehicles(transit_callback_index)

    # Search parameters.
    search_parameters = pywrapcp.DefaultRoutingSearchParameters()
    search_parameters.first_solution_strategy = (routing_enums_pb2.FirstSolutionStrategy.PATH_CHEAPEST_ARC)
    
    # Solution.
    solution = routing.SolveWithParameters(search_parameters)
    
    return manager, routing, solution

# %%
def get_routes(solution, routing, manager):
  routes = []
  for route_nbr in range(routing.vehicles()):
    index = routing.Start(route_nbr)
    route = [manager.IndexToNode(index)]
    while not routing.IsEnd(index):
      index = solution.Value(routing.NextVar(index))
      route.append(manager.IndexToNode(index))
    routes.append(route)
  return routes

# %%
def assign_order(order_coord, inputs, paths):
    print("New order coord", order_coord)
    # Try assign to available riders.
    order_assigned = False
    for rider, path in paths.items():
        print('RIDER {}'.format(rider), ' is active {}'.format(path['active']))
        if path['active']: continue # Cannot assign order to a rider already employed on a path.
        
        # Create the data to optimize the path.
        time_tracker = path['time_tracker'].copy()
        time_tracker.append(inputs['time'])
        nodes_coord = path['nodes_coord'].copy() 
        nodes_coord.append(order_coord) # Add the node to the established path of the rider.
        time_matrix = compute_time_matrix(nodes_coord) # Update the time matrix with the new nodes.
        
        print('Nodes coordinates', nodes_coord)
        
        manager, routing, solution = tsp_path(time_matrix)
        routes = get_routes(solution, routing, manager)
        
        new_nodes = routes[0][1:-1] # Remove first and last.
        
        # Check if path is within conditions. 
        total_time = 0
        last_node = 0
        must_leave = float('inf')
        for node in new_nodes:   
            total_time += time_matrix[last_node][node]
            last_node = node
            
            # Check if time permits
            time_permits = time_tracker[node - 1] + 30 > inputs['time'] + total_time # Time to get there
            if not time_permits: break
            if time_tracker[node - 1] + 30 - total_time < must_leave:
                must_leave = time_tracker[node - 1] + 30 - total_time
        
        total_time += time_matrix[last_node][0]
        
        # Add the path.
        paths[rider]['nodes_coord'] = nodes_coord
        paths[rider]['time_tracker'] = time_tracker
        paths[rider]['path'] = routes[0]
        paths[rider]['must_leave'] = must_leave
        paths[rider]['will_return'] = inputs['time'] + total_time
        paths[rider]['active'] = must_leave == inputs['time']          

        # Order has been assigned
        order_assigned = True
        break
    
    # Handle edge cases.
    if not order_assigned:
        filtered_paths = {k: v for k, v in paths.items() if not v['active']}
        print('FILTERED',len(filtered_paths))
        # Closest rider
        if len(filtered_paths) > 0:
            rider = ''
            new_path = []
            for rider, path in paths.items():
                time_tracker = path['time_tracker'].copy()
                time_tracker.append(inputs['time'])
                nodes_coord = path['nodes_coord'].copy() 
                nodes_coord.append(order_coord) # Add the node to the established path of the rider.
                time_matrix = compute_time_matrix(nodes_coord) # Update the time matrix with the new nodes.
                
                
                
        
        # Assign to rider on road
        else:
        
        
        
        
    return paths

# %%
def describe_paths(paths):
    total_paths = 0
    total_orders = 0
    for rider, path in paths.items():
        print('Rider {}'.format(rider))
        
        orders_handled = 0
        paths_handled = len(path['completed'])
        for path in path['completed']:
            orders_handled += len(path[1:-1])
            
        print('  > Paths handled: {}'.format(paths_handled))
        print('  > Orders handled: {}\n'.format(orders_handled))
        
        total_paths += paths_handled
        total_orders += orders_handled
    
    print('Total paths: {}'.format(total_paths))
    print('Total orders: {}'.format(total_orders))

# %%
# Inputs.
num_orders = 36
timeframe = 180 # minutes
num_riders = 2

cooking_time = 5
delivery_max = 30

inputs = {
    'time': 0,
    'hub_coord': (0,0),
    'prep_time': 5,
    'delivery_max': 30,
    'verbose': True,
    'open_orders': []
}

# ---------------------------
orders = [random.randrange(timeframe) for x in range(num_orders)] # Can be improved with density function
orders.sort()
# ---------------------------

paths = init_paths(num_riders, hub_coord)
while timeframe + 30 >= inputs['time']:
    print('time', inputs['time'])
    # Update riders active status.
    # - False, waiting to leave
    # - True, active on a path
    for rider, path in paths.items():
        # Rider becomes active.
        if path['must_leave'] == inputs['time']:
            paths[rider]['active'] = True
            
        # Rider becomes inactive, reset all paths specifics.
        if path['will_return'] == inputs['time']:
            paths[rider]['completed'].append(path['path'])
            paths[rider]['nodes_coord'] = [(0,0)]
            paths[rider]['time_tracker'] = []
            paths[rider]['must_leave'] = float('inf')
            paths[rider]['will_return'] = float('inf')
            paths[rider]['active'] = False
            print('PATH', path['path'])
        
        # Describe the riders path.
        if inputs['verbose'] & path['active']: describe_path(rider, path)
        
    
    for order in orders:
        if order == inputs['time']:
            print('New order')
            order_coord = random_node()
            print(order_coord)
            # Assign order to rider.
            new_paths = assign_order(order_coord, inputs, paths)
            paths = new_paths
    
    # Update time passaed.
    inputs['time'] += 1
# Out:
# time 0
# time 1
# time 2
# time 3
# time 4
# time 5
# time 6
# time 7
# time 8
# time 9
# time 10
# New order
# (0.15993635639080384, 9.263179356429667)
# New order coord (0.15993635639080384, 9.263179356429667)
# RIDER r0  is active False
# Nodes coordinates [(0, 0), (0.15993635639080384, 9.263179356429667)]
# time 11
# time 12
# New order
# (4.521271605779454, -7.692286715805952)
# New order coord (4.521271605779454, -7.692286715805952)
# RIDER r0  is active False
# Nodes coordinates [(0, 0), (0.15993635639080384, 9.263179356429667), (4.521271605779454, -7.692286715805952)]
# time 13
# time 14
# time 15
# time 16
# New order
# (0.2895248063742069, -7.476649464266188)
# New order coord (0.2895248063742069, -7.476649464266188)
# RIDER r0  is active False
# Nodes coordinates [(0, 0), (0.15993635639080384, 9.263179356429667), (4.521271605779454, -7.692286715805952), (0.2895248063742069, -7.476649464266188)]
# time 17
# time 18
# time 19
# time 20
# time 21
# Rider r0
# Status True
# Time on path: 48
# time 22
# Rider r0
# Status True
# Time on path: 48
# time 23
# Rider r0
# Status True
# Time on path: 48
# time 24
# Rider r0
# Status True
# Time on path: 48
# time 25
# Rider r0
# Status True
# Time on path: 48
# New order
# (4.987807073130729, -3.630614148146525)
# New order coord (4.987807073130729, -3.630614148146525)
# RIDER r0  is active True
# RIDER r1  is active False
# Nodes coordinates [(0, 0), (4.987807073130729, -3.630614148146525)]
# time 26
# Rider r0
# Status True
# Time on path: 48
# time 27
# Rider r0
# Status True
# Time on path: 48
# time 28
# Rider r0
# Status True
# Time on path: 48
# time 29
# Rider r0
# Status True
# Time on path: 48
# time 30
# Rider r0
# Status True
# Time on path: 48
# time 31
# Rider r0
# Status True
# Time on path: 48
# New order
# (5.83698564912727, 0.25400214430435014)
# New order coord (5.83698564912727, 0.25400214430435014)
# RIDER r0  is active True
# RIDER r1  is active False
# Nodes coordinates [(0, 0), (4.987807073130729, -3.630614148146525), (5.83698564912727, 0.25400214430435014)]
# New order
# (-1.753591374277354, 9.448764725555769)
# New order coord (-1.753591374277354, 9.448764725555769)
# RIDER r0  is active True
# RIDER r1  is active False
# Nodes coordinates [(0, 0), (4.987807073130729, -3.630614148146525), (5.83698564912727, 0.25400214430435014), (-1.753591374277354, 9.448764725555769)]
# time 32
# Rider r0
# Status True
# Time on path: 48
# time 33
# Rider r0
# Status True
# Time on path: 48
# New order
# (-5.291282617475709, 1.481321530611588)
# New order coord (-5.291282617475709, 1.481321530611588)
# RIDER r0  is active True
# RIDER r1  is active False
# Nodes coordinates [(0, 0), (4.987807073130729, -3.630614148146525), (5.83698564912727, 0.25400214430435014), (-1.753591374277354, 9.448764725555769), (-5.291282617475709, 1.481321530611588)]
# New order
# (0.32396273282337706, 9.366214309315696)
# New order coord (0.32396273282337706, 9.366214309315696)
# RIDER r0  is active True
# RIDER r1  is active False
# Nodes coordinates [(0, 0), (4.987807073130729, -3.630614148146525), (5.83698564912727, 0.25400214430435014), (-1.753591374277354, 9.448764725555769), (-5.291282617475709, 1.481321530611588), (0.32396273282337706, 9.366214309315696)]
# time 34
# Rider r0
# Status True
# Time on path: 48
# New order
# (-2.157637082218984, -1.582335988253705)
# New order coord (-2.157637082218984, -1.582335988253705)
# RIDER r0  is active True
# RIDER r1  is active False
# Nodes coordinates [(0, 0), (4.987807073130729, -3.630614148146525), (5.83698564912727, 0.25400214430435014), (-1.753591374277354, 9.448764725555769), (-5.291282617475709, 1.481321530611588), (0.32396273282337706, 9.366214309315696), (-2.157637082218984, -1.582335988253705)]
# time 35
# Rider r0
# Status True
# Time on path: 48
# time 36
# Rider r0
# Status True
# Time on path: 48
# New order
# (-2.2258428773435748, 9.65704288515635)
# New order coord (-2.2258428773435748, 9.65704288515635)
# RIDER r0  is active True
# RIDER r1  is active False
# Nodes coordinates [(0, 0), (4.987807073130729, -3.630614148146525), (5.83698564912727, 0.25400214430435014), (-1.753591374277354, 9.448764725555769), (-5.291282617475709, 1.481321530611588), (0.32396273282337706, 9.366214309315696), (-2.157637082218984, -1.582335988253705), (-2.2258428773435748, 9.65704288515635)]
# time 37
# Rider r0
# Status True
# Time on path: 48
# time 38
# Rider r0
# Status True
# Time on path: 48
# time 39
# Rider r0
# Status True
# Time on path: 48
# time 40
# Rider r0
# Status True
# Time on path: 48
# time 41
# Rider r0
# Status True
# Time on path: 48
# time 42
# Rider r0
# Status True
# Time on path: 48
# New order
# (1.0063759305502409, 9.046109336158835)
# New order coord (1.0063759305502409, 9.046109336158835)
# RIDER r0  is active True
# RIDER r1  is active False
# Nodes coordinates [(0, 0), (4.987807073130729, -3.630614148146525), (5.83698564912727, 0.25400214430435014), (-1.753591374277354, 9.448764725555769), (-5.291282617475709, 1.481321530611588), (0.32396273282337706, 9.366214309315696), (-2.157637082218984, -1.582335988253705), (-2.2258428773435748, 9.65704288515635), (1.0063759305502409, 9.046109336158835)]
# time 43
# Rider r0
# Status True
# Time on path: 48
# time 44
# Rider r0
# Status True
# Time on path: 48
# time 45
# Rider r0
# Status True
# Time on path: 48
# time 46
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 47
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# New order
# (-1.4980343018978142, -3.10113910575635)
# New order coord (-1.4980343018978142, -3.10113910575635)
# RIDER r0  is active True
# RIDER r1  is active True
# FILTERED 0
# time 48
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 49
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 50
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 51
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 52
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 53
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 54
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 55
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 56
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 57
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 58
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# New order
# (-3.436066210634015, 6.12259324204081)
# New order coord (-3.436066210634015, 6.12259324204081)
# RIDER r0  is active True
# RIDER r1  is active True
# FILTERED 0
# time 59
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 60
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 61
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# New order
# (-0.7280052620223408, -0.8257023085751027)
# New order coord (-0.7280052620223408, -0.8257023085751027)
# RIDER r0  is active True
# RIDER r1  is active True
# FILTERED 0
# time 62
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 63
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 64
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 65
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 66
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 67
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 68
# Rider r0
# Status True
# Time on path: 48
# Rider r1
# Status True
# Time on path: 37
# time 69
# PATH [0, 3, 2, 1, 0]
# Rider r1
# Status True
# Time on path: 37
# time 70
# Rider r1
# Status True
# Time on path: 37
# New order
# (-1.805557521779183, -2.7137171038058896)
# New order coord (-1.805557521779183, -2.7137171038058896)
# RIDER r0  is active False
# Nodes coordinates [(0, 0), (-1.805557521779183, -2.7137171038058896)]
# time 71
# Rider r1
# Status True
# Time on path: 37
# time 72
# Rider r1
# Status True
# Time on path: 37
# time 73
# Rider r1
# Status True
# Time on path: 37
# New order
# (1.6618517095843586, 8.026977438688439)
# New order coord (1.6618517095843586, 8.026977438688439)
# RIDER r0  is active False
# Nodes coordinates [(0, 0), (-1.805557521779183, -2.7137171038058896), (1.6618517095843586, 8.026977438688439)]
# time 74
# Rider r1
# Status True
# Time on path: 37
# time 75
# Rider r1
# Status True
# Time on path: 37
# time 76
# Rider r1
# Status True
# Time on path: 37
# time 77
# Rider r1
# Status True
# Time on path: 37
# New order
# (5.147704894761205, -6.878455880790161)
# New order coord (5.147704894761205, -6.878455880790161)
# RIDER r0  is active False
# Nodes coordinates [(0, 0), (-1.805557521779183, -2.7137171038058896), (1.6618517095843586, 8.026977438688439), (5.147704894761205, -6.878455880790161)]
# time 78
# Rider r1
# Status True
# Time on path: 37
# time 79
# Rider r1
# Status True
# Time on path: 37
# time 80
# Rider r1
# Status True
# Time on path: 37
# time 81
# Rider r1
# Status True
# Time on path: 37
# time 82
# Rider r1
# Status True
# Time on path: 37
# time 83
# PATH [0, 6, 4, 7, 3, 5, 8, 2, 1, 0]
# time 84
# time 85
# time 86
# Rider r0
# Status True
# Time on path: 40
# time 87
# Rider r0
# Status True
# Time on path: 40
# time 88
# Rider r0
# Status True
# Time on path: 40
# time 89
# Rider r0
# Status True
# Time on path: 40
# time 90
# Rider r0
# Status True
# Time on path: 40
# time 91
# Rider r0
# Status True
# Time on path: 40
# time 92
# Rider r0
# Status True
# Time on path: 40
# time 93
# Rider r0
# Status True
# Time on path: 40
# time 94
# Rider r0
# Status True
# Time on path: 40
# time 95
# Rider r0
# Status True
# Time on path: 40
# New order
# (-5.595635997620929, -6.886842480076972)
# New order coord (-5.595635997620929, -6.886842480076972)
# RIDER r0  is active True
# RIDER r1  is active False
# Nodes coordinates [(0, 0), (-5.595635997620929, -6.886842480076972)]
# time 96
# Rider r0
# Status True
# Time on path: 40
# New order
# (-3.1242352555084283, 8.209114168399083)
# New order coord (-3.1242352555084283, 8.209114168399083)
# RIDER r0  is active True
# RIDER r1  is active False
# Nodes coordinates [(0, 0), (-5.595635997620929, -6.886842480076972), (-3.1242352555084283, 8.209114168399083)]
# New order
# (5.635993557435431, 2.086383931728885)
# New order coord (5.635993557435431, 2.086383931728885)
# RIDER r0  is active True
# RIDER r1  is active False
# Nodes coordinates [(0, 0), (-5.595635997620929, -6.886842480076972), (-3.1242352555084283, 8.209114168399083), (5.635993557435431, 2.086383931728885)]
# time 97
# Rider r0
# Status True
# Time on path: 40
# time 98
# Rider r0
# Status True
# Time on path: 40
# time 99
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 100
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 101
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 102
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# New order
# (-8.326365699806853, -0.7161498222674082)
# New order coord (-8.326365699806853, -0.7161498222674082)
# RIDER r0  is active True
# RIDER r1  is active True
# FILTERED 0
# time 103
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# New order
# (1.7973177708106243, -2.9858819365718223)
# New order coord (1.7973177708106243, -2.9858819365718223)
# RIDER r0  is active True
# RIDER r1  is active True
# FILTERED 0
# time 104
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 105
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 106
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# New order
# (2.8235808563475726, 5.2947910168770544)
# New order coord (2.8235808563475726, 5.2947910168770544)
# RIDER r0  is active True
# RIDER r1  is active True
# FILTERED 0
# New order
# (6.146552248494525, -5.175810844590366)
# New order coord (6.146552248494525, -5.175810844590366)
# RIDER r0  is active True
# RIDER r1  is active True
# FILTERED 0
# time 107
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 108
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# New order
# (8.157035959459451, -3.8035239575408233)
# New order coord (8.157035959459451, -3.8035239575408233)
# RIDER r0  is active True
# RIDER r1  is active True
# FILTERED 0
# time 109
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# New order
# (1.122427724522978, 4.7485935743101075)
# New order coord (1.122427724522978, 4.7485935743101075)
# RIDER r0  is active True
# RIDER r1  is active True
# FILTERED 0
# time 110
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 111
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 112
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 113
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 114
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 115
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 116
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 117
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 118
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# New order
# (2.1449643614085128, -0.8610604415094162)
# New order coord (2.1449643614085128, -0.8610604415094162)
# RIDER r0  is active True
# RIDER r1  is active True
# FILTERED 0
# time 119
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# New order
# (6.315551772727906, 2.6867016072170697)
# New order coord (6.315551772727906, 2.6867016072170697)
# RIDER r0  is active True
# RIDER r1  is active True
# FILTERED 0
# time 120
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 121
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 122
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 123
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 124
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 125
# Rider r0
# Status True
# Time on path: 40
# Rider r1
# Status True
# Time on path: 53
# time 126
# PATH [0, 1, 3, 2, 0]
# Rider r1
# Status True
# Time on path: 53
# time 127
# Rider r1
# Status True
# Time on path: 53
# time 128
# Rider r1
# Status True
# Time on path: 53
# time 129
# Rider r1
# Status True
# Time on path: 53
# time 130
# Rider r1
# Status True
# Time on path: 53
# time 131
# Rider r1
# Status True
# Time on path: 53
# time 132
# Rider r1
# Status True
# Time on path: 53
# time 133
# Rider r1
# Status True
# Time on path: 53
# time 134
# Rider r1
# Status True
# Time on path: 53
# time 135
# Rider r1
# Status True
# Time on path: 53
# time 136
# Rider r1
# Status True
# Time on path: 53
# time 137
# Rider r1
# Status True
# Time on path: 53
# time 138
# Rider r1
# Status True
# Time on path: 53
# New order
# (-0.6596671458088971, 5.134818996019112)
# New order coord (-0.6596671458088971, 5.134818996019112)
# RIDER r0  is active False
# Nodes coordinates [(0, 0), (-0.6596671458088971, 5.134818996019112)]
# time 139
# Rider r1
# Status True
# Time on path: 53
# time 140
# Rider r1
# Status True
# Time on path: 53
# time 141
# Rider r1
# Status True
# Time on path: 53
# New order
# (-0.6824479365519781, 4.749012994536548)
# New order coord (-0.6824479365519781, 4.749012994536548)
# RIDER r0  is active False
# Nodes coordinates [(0, 0), (-0.6596671458088971, 5.134818996019112), (-0.6824479365519781, 4.749012994536548)]
# New order
# (4.160346075447879, -0.01977608540766354)
# New order coord (4.160346075447879, -0.01977608540766354)
# RIDER r0  is active False
# Nodes coordinates [(0, 0), (-0.6596671458088971, 5.134818996019112), (-0.6824479365519781, 4.749012994536548), (4.160346075447879, -0.01977608540766354)]
# time 142
# Rider r0
# Status True
# Time on path: 30
# Rider r1
# Status True
# Time on path: 53
# time 143
# Rider r0
# Status True
# Time on path: 30
# Rider r1
# Status True
# Time on path: 53
# time 144
# Rider r0
# Status True
# Time on path: 30
# Rider r1
# Status True
# Time on path: 53
# time 145
# Rider r0
# Status True
# Time on path: 30
# Rider r1
# Status True
# Time on path: 53
# time 146
# Rider r0
# Status True
# Time on path: 30
# Rider r1
# Status True
# Time on path: 53
# time 147
# Rider r0
# Status True
# Time on path: 30
# Rider r1
# Status True
# Time on path: 53
# New order
# (7.192902751785724, -3.6568397385057714)
# New order coord (7.192902751785724, -3.6568397385057714)
# RIDER r0  is active True
# RIDER r1  is active True
# FILTERED 0
# time 148
# Rider r0
# Status True
# Time on path: 30
# Rider r1
# Status True
# Time on path: 53
# time 149
# Rider r0
# Status True
# Time on path: 30
# Rider r1
# Status True
# Time on path: 53
# time 150
# Rider r0
# Status True
# Time on path: 30
# Rider r1
# Status True
# Time on path: 53
# time 151
# Rider r0
# Status True
# Time on path: 30
# Rider r1
# Status True
# Time on path: 53
# time 152
# Rider r0
# Status True
# Time on path: 30
# PATH [0, 3, 2, 1, 0]
# time 153
# Rider r0
# Status True
# Time on path: 30
# time 154
# Rider r0
# Status True
# Time on path: 30
# time 155
# Rider r0
# Status True
# Time on path: 30
# time 156
# Rider r0
# Status True
# Time on path: 30
# time 157
# Rider r0
# Status True
# Time on path: 30
# time 158
# Rider r0
# Status True
# Time on path: 30
# New order
# (6.677663633825809, -2.942485951429718)
# New order coord (6.677663633825809, -2.942485951429718)
# RIDER r0  is active True
# RIDER r1  is active False
# Nodes coordinates [(0, 0), (6.677663633825809, -2.942485951429718)]
# time 159
# Rider r0
# Status True
# Time on path: 30
# time 160
# Rider r0
# Status True
# Time on path: 30
# time 161
# Rider r0
# Status True
# Time on path: 30
# time 162
# Rider r0
# Status True
# Time on path: 30
# time 163
# Rider r0
# Status True
# Time on path: 30
# time 164
# Rider r0
# Status True
# Time on path: 30
# time 165
# Rider r0
# Status True
# Time on path: 30
# time 166
# Rider r0
# Status True
# Time on path: 30
# time 167
# Rider r0
# Status True
# Time on path: 30
# time 168
# Rider r0
# Status True
# Time on path: 30
# time 169
# Rider r0
# Status True
# Time on path: 30
# time 170
# Rider r0
# Status True
# Time on path: 30
# time 171
# Rider r0
# Status True
# Time on path: 30
# time 172
# PATH [0, 3, 2, 1, 0]
# time 173
# New order
# (-8.425818444259129, 0.9706820825880642)
# New order coord (-8.425818444259129, 0.9706820825880642)
# RIDER r0  is active False
# Nodes coordinates [(0, 0), (-8.425818444259129, 0.9706820825880642)]
# time 174
# time 175
# time 176
# Rider r1
# Status True
# Time on path: 1
# time 177
# PATH [0, 1, 0]
# New order
# (0.3556655476784101, 9.973775692820809)
# New order coord (0.3556655476784101, 9.973775692820809)
# RIDER r0  is active False
# Nodes coordinates [(0, 0), (-8.425818444259129, 0.9706820825880642), (0.3556655476784101, 9.973775692820809)]
# New order
# (3.9074380383988903, -4.8562684307302675)
# New order coord (3.9074380383988903, -4.8562684307302675)
# RIDER r0  is active False
# Nodes coordinates [(0, 0), (-8.425818444259129, 0.9706820825880642), (0.3556655476784101, 9.973775692820809), (3.9074380383988903, -4.8562684307302675)]
# time 178
# time 179
# time 180
# time 181
# time 182
# time 183
# time 184
# time 185
# time 186
# time 187
# time 188
# time 189
# time 190
# time 191
# time 192
# time 193
# time 194
# time 195
# time 196
# Rider r0
# Status True
# Time on path: 22
# time 197
# Rider r0
# Status True
# Time on path: 22
# time 198
# Rider r0
# Status True
# Time on path: 22
# time 199
# Rider r0
# Status True
# Time on path: 22
# time 200
# Rider r0
# Status True
# Time on path: 22
# time 201
# Rider r0
# Status True
# Time on path: 22
# time 202
# Rider r0
# Status True
# Time on path: 22
# time 203
# Rider r0
# Status True
# Time on path: 22
# time 204
# Rider r0
# Status True
# Time on path: 22
# time 205
# Rider r0
# Status True
# Time on path: 22
# time 206
# Rider r0
# Status True
# Time on path: 22
# time 207
# Rider r0
# Status True
# Time on path: 22
# time 208
# Rider r0
# Status True
# Time on path: 22
# time 209
# Rider r0
# Status True
# Time on path: 22
# time 210
# Rider r0
# Status True
# Time on path: 22

# %%
describe_paths(paths)
# Out:
# Rider r0
#   > Paths handled: 3
#   > Orders handled: 15
#
# Rider r1
#   > Paths handled: 3
#   > Orders handled: 10
#
# Total paths: 6
# Total orders: 25

# %%
paths['r0']['path']
# Out:
# [0, 3, 2, 1, 0]
